# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img = cv2.imread("goBoard.png")

# %%
plt.imshow(img)

# %% [markdown]
# ##Go Board Detection

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

dst = cv2.dilate(dst,None)

#En uygun değer için eşik değeri, görüntüye bağlı olarak değişebilir.
img[dst>0.01*dst.max()]=[0,0,255]

plt.imshow(img)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %% [markdown]
# ##Detection Go Board with Stones

# %%
img_stones = cv2.imread("akrales-160307-0970-a-0127-0.jpg")

# %%
plt.imshow(img_stones)

# %%
gray1 = cv2.cvtColor(img_stones,cv2.COLOR_BGR2GRAY)
circles1 = cv2.HoughCircles(gray1,cv2.HOUGH_GRADIENT,1,10,param1=180,param2=27,minRadius=20,maxRadius=60)
circles1 = np.uint16(np.around(circles1))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(img_stones,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(img_stones,(i[0],i[1]),2,(0,0,255),3)
    
plt.imshow(img_stones)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %% [markdown]
# Real Board Sample

# %%
img_real_stones = cv2.imread("weiqi12.jpg")

# %%
gray_real = cv2.cvtColor(img_real_stones,cv2.COLOR_BGR2GRAY)
circles_real = cv2.HoughCircles(gray_real,cv2.HOUGH_GRADIENT,1,10,param1=180,param2=27,minRadius=20,maxRadius=60)
circles_real = np.uint16(np.around(circles_real))
for i in circles[0,:]:
    # draw the outer circle
    cv2.circle(img_real_stones,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
    cv2.circle(img_real_stones,(i[0],i[1]),2,(0,0,255),3)
    
plt.imshow(img_real_stones)
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %%
#Görüldüğü gibi gerçek hayat örneği tahtanın eğimli olması nedeniyle başarısız olduğu söylenebilir
